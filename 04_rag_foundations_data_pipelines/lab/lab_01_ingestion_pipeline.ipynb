# %% [markdown]
# # Lab 1: Document Ingestion Pipeline
#
# ## Learning Objectives
# By the end of this lab, you will:
# - Evaluate document ingestion frameworks and their trade-offs
# - Implement a dispatcher pattern for multi-format document handling
# - Build a text cleaning pipeline for PDF and web content
# - Create a standardized Document data model for your RAG system
#
# ## Setup
# Run the cell below to install required libraries.

# %%
# !uv pip install beautifulsoup4 requests chardet -q

# %%
# !uv pip install pandas
# Out:
# Using Python 3.12.2 environment at: /Users/abdulelah./Downloads/sdaia/.venv
# Resolved 4 packages in 1.46s
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)-------------------     0 B/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 8.74 KiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 8.74 KiB/4.96 MiB
# numpy                ------------------------------ 8.74 KiB/4.96 MiB
# ⠙ Preparing packages... (0/2)-------------------     0 B/9.43 MiB
# numpy                ------------------------------ 24.74 KiB/4.96 MiB
# ⠙ Preparing packages... (0/2)-------------------     0 B/9.43 MiB
# numpy                ------------------------------ 40.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)-------------------     0 B/9.43 MiB
# numpy                ------------------------------ 40.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)-------------------     0 B/9.43 MiB
# numpy                ------------------------------ 54.69 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)-------------------     0 B/9.43 MiB
# numpy                ------------------------------ 54.69 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 4.74 KiB/9.43 MiB
# numpy                ------------------------------ 64.18 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 4.74 KiB/9.43 MiB
# numpy                ------------------------------ 64.18 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 16.00 KiB/9.43 MiB
# numpy                ------------------------------ 72.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 16.00 KiB/9.43 MiB
# numpy                ------------------------------ 72.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 32.00 KiB/9.43 MiB
# numpy                ------------------------------ 88.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 32.00 KiB/9.43 MiB
# numpy                ------------------------------ 88.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 48.00 KiB/9.43 MiB
# numpy                ------------------------------ 104.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 48.00 KiB/9.43 MiB
# numpy                ------------------------------ 104.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 64.00 KiB/9.43 MiB
# numpy                ------------------------------ 120.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 64.00 KiB/9.43 MiB
# numpy                ------------------------------ 120.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 80.00 KiB/9.43 MiB
# numpy                ------------------------------ 136.63 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 80.00 KiB/9.43 MiB
# numpy                ------------------------------ 136.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 80.00 KiB/9.43 MiB
# numpy                ------------------------------ 136.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 96.00 KiB/9.43 MiB
# numpy                ------------------------------ 136.74 KiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 112.00 KiB/9.43 MiB
# numpy                ------------------------------ 136.74 KiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 128.00 KiB/9.43 MiB
# numpy                ------------------------------ 168.74 KiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 176.00 KiB/9.43 MiB
# numpy                ------------------------------ 328.74 KiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 288.00 KiB/9.43 MiB
# numpy                ------------------------------ 488.74 KiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 416.00 KiB/9.43 MiB
# numpy                ------------------------------ 552.74 KiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 464.00 KiB/9.43 MiB
# numpy                ------------------------------ 568.74 KiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 464.00 KiB/9.43 MiB
# numpy                ------------------------------ 1.06 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 1008.00 KiB/9.43 MiB
# numpy                ------------------------------ 1.12 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)------------------- 1.06 MiB/9.43 MiB
# numpy                ------------------------------ 1.45 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.38 MiB/9.43 MiB
# numpy                ------------------------------ 1.45 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.38 MiB/9.43 MiB
# numpy                ------------------------------ 1.45 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.39 MiB/9.43 MiB
# numpy                ------------------------------ 1.46 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 1.39 MiB/9.43 MiB
# numpy                ------------------------------ 1.46 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 1.39 MiB/9.43 MiB
# numpy                ------------------------------ 1.46 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 1.41 MiB/9.43 MiB
# numpy                ------------------------------ 1.48 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 1.41 MiB/9.43 MiB
# numpy                ------------------------------ 1.48 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 1.41 MiB/9.43 MiB
# numpy                ------------------------------ 1.48 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 1.42 MiB/9.43 MiB
# numpy                ------------------------------ 1.49 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 1.42 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 1.42 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 1.44 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 1.44 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 1.44 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 1.45 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.47 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.47 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.48 MiB/9.43 MiB
# numpy                ------------------------------ 1.51 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.50 MiB/9.43 MiB
# numpy                ------------------------------ 1.52 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.50 MiB/9.43 MiB
# numpy                ------------------------------ 1.52 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.52 MiB/9.43 MiB
# numpy                ------------------------------ 1.54 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.52 MiB/9.43 MiB
# numpy                ------------------------------ 1.54 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 1.53 MiB/9.43 MiB
# numpy                ------------------------------ 1.56 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 1.53 MiB/9.43 MiB
# numpy                ------------------------------ 1.56 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 1.53 MiB/9.43 MiB
# numpy                ------------------------------ 1.56 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 1.55 MiB/9.43 MiB
# numpy                ------------------------------ 1.57 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 1.55 MiB/9.43 MiB
# numpy                ------------------------------ 1.57 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 1.56 MiB/9.43 MiB
# numpy                ------------------------------ 1.59 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 1.56 MiB/9.43 MiB
# numpy                ------------------------------ 1.60 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 1.56 MiB/9.43 MiB
# numpy                ------------------------------ 1.62 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 1.56 MiB/9.43 MiB
# numpy                ------------------------------ 1.65 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 1.58 MiB/9.43 MiB
# numpy                ------------------------------ 1.68 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 1.61 MiB/9.43 MiB
# numpy                ------------------------------ 1.68 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 1.61 MiB/9.43 MiB
# numpy                ------------------------------ 1.70 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 1.66 MiB/9.43 MiB
# numpy                ------------------------------ 1.71 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 1.66 MiB/9.43 MiB
# numpy                ------------------------------ 1.71 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)------------------- 1.70 MiB/9.43 MiB
# numpy                ------------------------------ 1.74 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)------------------- 1.73 MiB/9.43 MiB
# numpy                ------------------------------ 1.76 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)------------------- 1.73 MiB/9.43 MiB
# numpy                ------------------------------ 1.76 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)------------------- 1.75 MiB/9.43 MiB
# numpy                ------------------------------ 1.82 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.77 MiB/9.43 MiB
# numpy                ------------------------------ 1.87 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.80 MiB/9.43 MiB
# numpy                ------------------------------ 1.88 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.80 MiB/9.43 MiB
# numpy                ------------------------------ 1.96 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.83 MiB/9.43 MiB
# numpy                ------------------------------ 1.96 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 1.84 MiB/9.43 MiB
# numpy                ------------------------------ 2.00 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 1.91 MiB/9.43 MiB
# numpy                ------------------------------ 2.01 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 2.03 MiB/9.43 MiB
# numpy                ------------------------------ 2.01 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 2.05 MiB/9.43 MiB
# numpy                ------------------------------ 2.06 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 2.11 MiB/9.43 MiB
# numpy                ------------------------------ 2.06 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 2.12 MiB/9.43 MiB
# numpy                ------------------------------ 2.10 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 2.20 MiB/9.43 MiB
# numpy                ------------------------------ 2.10 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 2.22 MiB/9.43 MiB
# numpy                ------------------------------ 2.12 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 2.23 MiB/9.43 MiB
# numpy                ------------------------------ 2.13 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 2.25 MiB/9.43 MiB
# numpy                ------------------------------ 2.15 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 2.25 MiB/9.43 MiB
# numpy                ------------------------------ 2.20 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 2.27 MiB/9.43 MiB
# numpy                ------------------------------ 2.21 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 2.27 MiB/9.43 MiB
# numpy                ------------------------------ 2.23 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 2.30 MiB/9.43 MiB
# numpy                ------------------------------ 2.26 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 2.33 MiB/9.43 MiB
# numpy                ------------------------------ 2.26 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 2.33 MiB/9.43 MiB
# numpy                ------------------------------ 2.26 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 2.34 MiB/9.43 MiB
# numpy                ------------------------------ 2.27 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 2.38 MiB/9.43 MiB
# numpy                ------------------------------ 2.29 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 2.39 MiB/9.43 MiB
# numpy                ------------------------------ 2.29 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 2.41 MiB/9.43 MiB
# numpy                ------------------------------ 2.54 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 2.58 MiB/9.43 MiB
# numpy                ------------------------------ 3.00 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 2.98 MiB/9.43 MiB
# numpy                ------------------------------ 3.45 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.25 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)------------------- 3.40 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠧ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠇ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠋ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠙ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 3.57 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 3.59 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 3.61 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠹ Preparing packages... (0/2)------------------- 3.62 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.64 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.64 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.65 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.67 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.68 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.70 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.72 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.73 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.75 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)------------------- 3.76 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)m------------------ 3.78 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)m------------------ 3.79 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)m------------------ 3.81 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)m------------------ 3.82 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)m------------------ 3.84 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠸ Preparing packages... (0/2)m------------------ 3.86 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.87 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.87 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.89 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.90 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.91 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.92 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.93 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.95 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠼ Preparing packages... (0/2)m------------------ 3.97 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)m------------------ 3.98 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)m------------------ 4.00 MiB/9.43 MiB
# numpy                ------------------------------ 3.96 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)m------------------ 4.02 MiB/9.43 MiB
# numpy                ------------------------------ 3.98 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)m------------------ 4.02 MiB/9.43 MiB
# numpy                ------------------------------ 3.99 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)m------------------ 4.02 MiB/9.43 MiB
# numpy                ------------------------------ 3.99 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)m------------------ 4.02 MiB/9.43 MiB
# numpy                ------------------------------ 4.28 MiB/4.96 MiB
# ⠴ Preparing packages... (0/2)2m----------------- 4.12 MiB/9.43 MiB
# numpy                ------------------------------ 4.29 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)2m----------------- 4.12 MiB/9.43 MiB
# numpy                ------------------------------ 4.45 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)2m----------------- 4.12 MiB/9.43 MiB
# numpy                ------------------------------ 4.60 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)2m----------------- 4.12 MiB/9.43 MiB
# numpy                ------------------------------ 4.71 MiB/4.96 MiB
# ⠦ Preparing packages... (0/2)---------------- 4.48 MiB/9.43 MiB
# ⠦ Preparing packages... (0/2)---------------- 4.58 MiB/9.43 MiB
# ⠧ Preparing packages... (1/2)---------------- 4.71 MiB/9.43 MiB
# ⠇ Preparing packages... (1/2)0m------------- 5.37 MiB/9.43 MiB
# ⠇ Preparing packages... (1/2)0m------------- 5.37 MiB/9.43 MiB
# ⠇ Preparing packages... (1/2)0m------------- 5.38 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)0m------------- 5.40 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)0m------------- 5.40 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)0m------------- 5.41 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)0m------------- 5.43 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)0m------------- 5.45 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)0m------------- 5.46 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)0m------------- 5.46 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)0m------------- 5.48 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)0m------------- 5.49 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)0m------------- 5.51 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)0m------------- 5.52 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)0m------------- 5.54 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)0m------------- 5.56 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)0m------------- 5.56 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)0m------------- 5.57 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)0m------------- 5.62 MiB/9.43 MiB
# ⠸ Preparing packages... (1/2)0m------------- 5.63 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.66 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.66 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.68 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.70 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.71 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.73 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.74 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)30m------------ 5.79 MiB/9.43 MiB
# ⠴ Preparing packages... (1/2)30m------------ 5.81 MiB/9.43 MiB
# ⠴ Preparing packages... (1/2)30m------------ 5.82 MiB/9.43 MiB
# ⠴ Preparing packages... (1/2)30m------------ 5.84 MiB/9.43 MiB
# ⠦ Preparing packages... (1/2)30m------------ 5.87 MiB/9.43 MiB
# ⠦ Preparing packages... (1/2)30m------------ 5.92 MiB/9.43 MiB
# ⠦ Preparing packages... (1/2)30m------------ 5.93 MiB/9.43 MiB
# ⠦ Preparing packages... (1/2)----------- 5.98 MiB/9.43 MiB
# ⠧ Preparing packages... (1/2)----------- 5.99 MiB/9.43 MiB
# ⠧ Preparing packages... (1/2)----------- 6.02 MiB/9.43 MiB
# ⠧ Preparing packages... (1/2)----------- 6.04 MiB/9.43 MiB
# ⠧ Preparing packages... (1/2)----------- 6.07 MiB/9.43 MiB
# ⠧ Preparing packages... (1/2)----------- 6.12 MiB/9.43 MiB
# ⠇ Preparing packages... (1/2)----------- 6.13 MiB/9.43 MiB
# ⠇ Preparing packages... (1/2)----------- 6.18 MiB/9.43 MiB
# ⠇ Preparing packages... (1/2)----------- 6.20 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)----------- 6.24 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)---------- 6.29 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)---------- 6.31 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)---------- 6.42 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)---------- 6.44 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)---------- 6.61 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)---------- 7.08 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)---------- 7.48 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)---------- 7.90 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 8.37 MiB/9.43 MiB
# ⠸ Preparing packages... (1/2)---------- 8.80 MiB/9.43 MiB
# ⠼ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠴ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠦ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠧ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠇ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠋ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)---------- 9.16 MiB/9.43 MiB
# ⠙ Preparing packages... (1/2)---------- 9.17 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.19 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.19 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.20 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.22 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.23 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.25 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.26 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.28 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.29 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.31 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.31 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.33 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.34 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.36 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.37 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.39 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.40 MiB/9.43 MiB
# ⠹ Preparing packages... (1/2)---------- 9.42 MiB/9.43 MiB
# ⠸ Preparing packages... (1/2)---------- 9.43 MiB/9.43 MiB
# ⠸ Preparing packages... (1/2)---------- 9.43 MiB/9.43 MiB
# Prepared 2 packages in 11.37s
# Installed 2 packages in 32ms
#  + numpy==2.4.4
#  + pandas==3.0.2

# %% [markdown]
# ---
# ## Part 1: Framework Selection
#
# Before writing any code, the most important decision in a RAG ingestion pipeline is **choosing the right document processing framework**. Each framework has distinct strengths depending on your document types, accuracy requirements, and deployment constraints.
#
# Here are the four major frameworks we'll compare:
#
# | Framework | Approach | Key Strength |
# |-----------|----------|-------------|
# | **Docling** | Local ML models for layout analysis | Best table extraction accuracy (97.9%) |
# | **Unstructured** | Multi-format connectors + partitioning | Widest format support, enterprise connectors |
# | **LlamaParse** | Cloud API with LLM-powered parsing | LLM-optimized markdown output |
# | **PyMuPDF** | Direct PDF rendering library | Fastest raw text extraction |
#
# Let's build a comparison matrix to see them side by side.

# %%
import pandas as pd

frameworks = {
    "Framework": ["Docling", "Unstructured", "LlamaParse", "PyMuPDF"],
    "Table Accuracy": ["97.9%", "~75%", "High", "Basic"],
    "Speed": ["~6s/page", "Variable", "API latency", "<1ms/page"],
    "Deployment": ["Local (GPU/CPU)", "Local / API", "Cloud API", "Local"],
    "License": ["MIT", "Apache 2.0", "Commercial", "AGPL"],
    "Best For": ["Research papers", "Enterprise multi-format", "LLM-optimized output", "High-throughput simple PDFs"]
}

df = pd.DataFrame(frameworks)
print(df.to_string(index=False))
# Out:
#    Framework Table Accuracy       Speed      Deployment    License                    Best For
#      Docling          97.9%    ~6s/page Local (GPU/CPU)        MIT             Research papers
# Unstructured           ~75%    Variable     Local / API Apache 2.0     Enterprise multi-format
#   LlamaParse           High API latency       Cloud API Commercial        LLM-optimized output
#      PyMuPDF          Basic   <1ms/page           Local       AGPL High-throughput simple PDFs

# %% [markdown]
# ### Exercise 1.1: Choose Your Framework
#
# Given the requirements below, which framework would you choose? Fill in your answers.

# %%
# TODO: For each scenario, assign the best framework name
# Choices: "Docling", "Unstructured", "LlamaParse", "PyMuPDF"

scenario_1 = "PyMuPDF"  # Processing 50,000 simple PDF invoices as fast as possible
scenario_2 = "Docling"  # Extracting tables from scientific papers with 2-column layouts
scenario_3 = "Unstructured"  # Building a connector for emails, PowerPoints, and PDFs
scenario_4 = "Docling"  # Data must stay on-premise, complex table extraction needed

# Validation
from tests import checks
checks.check_lab_1_1(scenario_1, scenario_2, scenario_3, scenario_4)
# Out:
# ✅ All correct!

# %% [markdown]
# ---
# ## Part 2: The Document Model
#
# Every ingestion pipeline needs a **standardized data model** — a common structure that all extractors produce, regardless of the source format. This is critical because:
#
# 1. **Downstream consistency**: Chunkers, embedders, and retrievers all expect the same shape of data.
# 2. **Metadata tracking**: We need to know where content came from, when it was ingested, and what type it is.
# 3. **Testability**: A clear contract makes it easy to validate extractor output.
#
# Let's define our `Document` dataclass.

# %%
from dataclasses import dataclass, field
from typing import Optional, Dict
from datetime import datetime, timezone

@dataclass
class Document:
    """Standardized representation of an ingested document."""
    content: str
    source: str
    title: Optional[str] = None
    doc_type: str = "unknown"
    author: Optional[str] = None
    ingested_at: str = field(
        default_factory=lambda: datetime.now(timezone.utc).isoformat()
    )
    word_count: int = 0
    extra_metadata: Dict = field(default_factory=dict)

    def __post_init__(self):
        if self.content and self.word_count == 0:
            self.word_count = len(self.content.split())

    def to_dict(self) -> dict:
        return {
            "content": self.content,
            "source": self.source,
            "metadata": {
                "title": self.title,
                "type": self.doc_type,
                "author": self.author,
                "word_count": self.word_count,
            }
        }

# Test it
doc = Document(
    content="Transformers use self-attention mechanisms to process sequences in parallel.",
    source="arxiv:1706.03762",
    title="Attention Is All You Need",
    doc_type="pdf"
)
print(f"Title: {doc.title}")
print(f"Word count: {doc.word_count}")
print(f"Dict keys: {list(doc.to_dict().keys())}")
# Out:
# Title: Attention Is All You Need
# Word count: 9
# Dict keys: ['content', 'source', 'metadata']

# %% [markdown]
# ---
# ## Part 3: Building Extractors
#
# Now let's build our first real extractor — a **web page extractor** using BeautifulSoup. The key challenges in web extraction are:
#
# - **Boilerplate removal**: Navigation, footers, ads, and scripts are noise.
# - **Content detection**: Finding the `<main>` or `<article>` tag where the real content lives.
# - **Graceful degradation**: Not every page has clean semantic HTML.

# %%
import requests
from bs4 import BeautifulSoup

def extract_web_page(url: str) -> Document:
    """Extract clean text content from a web page."""
    resp = requests.get(
        url,
        headers={"User-Agent": "ResearchAssistant/1.0"},
        timeout=10
    )
    resp.raise_for_status()
    
    soup = BeautifulSoup(resp.text, "html.parser")
    
    # Remove boilerplate elements
    for tag in soup(["script", "style", "nav", "footer", "header", "form"]):
        tag.decompose()
    
    # Find main content area
    content = soup.find("main") or soup.find("article") or soup.body
    text = content.get_text(separator="\n", strip=True) if content else ""
    title = soup.title.string if soup.title else url
    
    return Document(
        content=text,
        source=url,
        title=title,
        doc_type="web"
    )

# Test with a real page
try:
    doc = extract_web_page("https://en.wikipedia.org/wiki/Retrieval-augmented_generation")
    print(f"Title: {doc.title}")
    print(f"Word count: {doc.word_count}")
    print(f"Content preview: {doc.content[:300]}...")
except Exception as e:
    print(f"Could not fetch page (network issue): {e}")
    print("This is expected in offline environments.")
# Out:
# Title: Retrieval-augmented generation - Wikipedia
# Word count: 3396
# Content preview: From Wikipedia, the free encyclopedia
# Type of information retrieval using LLMs
# Retrieval-augmented generation
# (
# RAG
# ) is a technique that enables
# large language models
# (LLMs) to retrieve and incorporate new information from external data sources.
# [
# 1
# ]
# With RAG, LLMs first refer to a specified set o...

# %% [markdown]
# ---
# ## Part 4: Text Cleaning Pipeline
#
# Raw extracted text is almost never ready for embedding. Common issues include:
#
# - **Encoding artifacts**: Smart quotes, em-dashes, and other Unicode oddities
# - **Excessive whitespace**: Triple newlines, tab characters, trailing spaces
# - **PDF artifacts**: Page numbers ("Page 3 of 10"), hyphenated line breaks
#
# Let's build a cleaning pipeline that handles all of these.

# %%
import re
import unicodedata

def clean_text(text: str) -> str:
    """Master cleaning function for extracted text."""
    if not text:
        return ""
    
    # 1. Fix common encoding artifacts
    text = text.replace("\u2019", "'").replace("\u201c", '"').replace("\u201d", '"')
    text = unicodedata.normalize("NFC", text)
    
    # 2. Normalize whitespace
    text = re.sub(r"\n{3,}", "\n\n", text)  # Max 2 consecutive newlines
    text = re.sub(r"[ \t]+", " ", text)      # Collapse spaces/tabs
    
    # 3. Remove common PDF artifacts
    text = re.sub(r"Page \d+ of \d+", "", text)
    text = re.sub(r"-\n(\w)", r"\1", text)  # Fix hyphenated line breaks
    
    return text.strip()

# Test
dirty_text = """This is   a   messy     text.


Page 3 of 10

It has    extra     spaces and    too many


newlines.    The end-
ing of words gets broken."""

cleaned = clean_text(dirty_text)
print("BEFORE:")
print(repr(dirty_text[:200]))
print("\nAFTER:")
print(repr(cleaned[:200]))
# Out:
# BEFORE:
# 'This is   a   messy     text.\n\n\nPage 3 of 10\n\nIt has    extra     spaces and    too many\n\n\nnewlines.    The end-\ning of words gets broken.'
#
# AFTER:
# 'This is a messy text.\n\n\n\nIt has extra spaces and too many\n\nnewlines. The ending of words gets broken.'

# %% [markdown]
# ### Exercise 4.1: Extend the Cleaner
#
# The base `clean_text` function handles the most common issues, but real-world data has more noise. Add three new cleaning rules to handle emails, URLs, and standalone page numbers.

# %%
def clean_text_extended(text: str) -> str:
    """Extended cleaning with additional rules."""
    # Start with base cleaning
    text = clean_text(text)

    # Remove email addresses
    text = re.sub(r'\S+@\S+\.\S+', '', text)

    # Remove URLs
    text = re.sub(r'https?://\S+', '', text)

    # Remove lines that are just numbers (e.g., page numbers)
    text = re.sub(r'^\d+$', '', text, flags=re.MULTILINE)

    return text.strip()

# Test your implementation
test_text = """
Contact us at info@example.com for more details.
Visit https://www.example.com/research for the full paper.
42
This is the actual content we want to keep.
"""

result = clean_text_extended(test_text)
print(f"Result: {repr(result)}")

# Validation
from tests import checks
checks.check_lab_1_4(result)
# Out:
# Result: 'Contact us at  for more details.\nVisit  for the full paper.\n\nThis is the actual content we want to keep.'
# ✅ All cleaning rules working!

# %% [markdown]
# ---
# ## Part 5: The Dispatcher Pattern
#
# In a production RAG system, documents arrive in many formats. Rather than writing `if/elif` chains everywhere, we use a **dispatcher** — a single entry point that routes to the correct extractor based on the source type.
#
# This pattern provides:
# - **Single entry point**: Callers don't need to know which extractor to use.
# - **Easy extensibility**: Adding a new format means adding one branch.
# - **Consistent output**: Every extractor returns the same `Document` object.

# %%
from pathlib import Path

def extract_document(source: str) -> Document:
    """Route to the correct extractor based on source type."""
    if source.startswith(("http://", "https://")):
        return extract_web_page(source)
    
    ext = Path(source).suffix.lower()
    
    if ext in (".md", ".txt"):
        text = Path(source).read_text(encoding="utf-8")
        return Document(content=text, source=source, doc_type="text")
    elif ext == ".pdf":
        # In production: use Docling here
        # from docling.document_converter import DocumentConverter
        raise NotImplementedError(
            "PDF extraction requires Docling. "
            "Install with: pip install docling"
        )
    else:
        raise ValueError(f"Unsupported format: {ext}")

# Demonstrate the dispatcher
print("Dispatcher routing:")
for source in ["https://example.com/paper", "report.pdf", "notes.md", "data.csv"]:
    try:
        print(f"  {source} -> ", end="")
        # Don't actually call - just show routing logic
        if source.startswith("http"):
            print("extract_web_page()")
        elif source.endswith(".pdf"):
            print("extract_pdf() [Docling]")
        elif source.endswith((".md", ".txt")):
            print("extract_text_file()")
        else:
            print(f"ValueError: Unsupported format")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Dispatcher routing:
#   https://example.com/paper -> extract_web_page()
#   report.pdf -> extract_pdf() [Docling]
#   notes.md -> extract_text_file()
#   data.csv -> ValueError: Unsupported format

# %% [markdown]
# ### Exercise 5.1: Add Markdown Support
#
# Implement a dedicated markdown extractor that goes beyond plain text reading. It should:
# 1. Read the file content
# 2. Extract the title from the first `#` heading (if present)
# 3. Return a `Document` with `doc_type="markdown"`

# %%
# TODO: Implement a markdown extractor and integrate it into the dispatcher
def extract_markdowns(file_path: str) -> Document:
    """Extract content from a markdown file with basic metadata."""
    # TODO: Read the file content
    # TODO: Extract the title from the first # heading (if present)
    # TODO: Return a Document object with doc_type="markdown"
    
    # Hint: Use Path(file_path).read_text() and check lines starting with "# "
    pass
def extract_markdown(file_path: str) -> Document:
    """Extract content from a markdown file with basic metadata."""
    content = Path(file_path).read_text(encoding="utf-8")

    # Extract the title from the first "# " heading (if present)
    title = None
    for line in content.splitlines():
        if line.startswith("# "):
            title = line[2:].strip()
            break

    return Document(
        content=content,
        source=file_path,
        title=title,
        doc_type="markdown",
    )

# Test with an inline markdown string (simulating a file)
import tempfile
import os

sample_md = """# My Research Notes

## Introduction
This is a sample markdown document about RAG systems.

## Key Findings
- Chunking strategy matters most
- Overlap prevents context loss
"""

# Write to temp file for testing
with tempfile.NamedTemporaryFile(mode='w', suffix='.md', delete=False, encoding='utf-8') as f:
    f.write(sample_md)
    temp_path = f.name

try:
    doc = extract_markdown(temp_path)
    from tests import checks
    checks.check_lab_1_5(doc)
finally:
    os.unlink(temp_path)
# Out:
# ✅ Markdown extractor working!

# %% [markdown]
# ---
# ## Reflection Questions
#
# 1. **Trade-offs**: Why might you use PyMuPDF for a first pass and Docling as a fallback? What metric would you use to decide when to escalate?
# 2. **Data Model**: What additional metadata fields would you add to the Document class for a legal document processing system?
# 3. **Cleaning**: What risks come with aggressive text cleaning? Can you think of a case where removing "noise" actually removes important information?

# %% [markdown]
# *Your answers here:*
#
# 1. ...
# 2. ...
# 3. ...
